# %%
# Exp_Group2_BoTSORT_ByteTrack.ipynb

# ============================================
# 📌 設定 & 核心模組載入
# ============================================
import sys
import traceback
from pathlib import Path
import pandas as pd
import numpy as np
from datetime import datetime
import torch
import os

os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"

# --- 1. 定義根目錄 ---
root_path = Path().resolve()
while root_path.name != "YOLO11_Experiment" and root_path != root_path.parent:
    root_path = root_path.parent

sys.path.append(str(root_path / "utils"))

# --- 2. 匯入工具 ---
from source_utils import detect_source_type
from yolo_detector import load_model, run_predict_on_validation_set
from evaluation_metrics import compute_class_stability_with_id, compute_mot_metrics, compute_class_stability
from tracking_launcher import run_tracker # Group 2 專用
from voting_mechanism import run_class_voting

# ============================================
# 🛠️ 實驗設定 (Group 2)
# ============================================

# 全域時間戳
BATCH_TIMESTAMP = datetime.now().strftime("%Y%m%d-%H%M%S")

DETECTOR_WEIGHT = "weights/combined_freeze10.pt"

CONF_THRESHOLDS = [0.3, 0.4, 0.5]
IOU_THRESHOLDS = [0.3, 0.7]

TARGET_DATASETS = [
    "20230417_06_00230", "DSCN5480", "IMG_0004", "RCNX0029", "RCNX0062", 
    "RCNX0279", "group3_20240429_0248", "group5_20240429_0289", 
    "EK000061-20170904-1740", "IMG_0057"
]

TRACKERS = ['botsort', 'bytetrack', 'botsort_reid']

VOTING_SETTINGS = [
    {'method': 'majority', 'window': 3}, 
    {'method': 'majority', 'window': 5},
    {'method': 'majority', 'window': 10}, 
    {'method': 'majority', 'window': 'all'}, 
    {'method': 'weighted', 'window': 3}, 
    {'method': 'weighted', 'window': 5},
    {'method': 'weighted', 'window': 10}, 
    {'method': 'weighted', 'window': 'all'},
]

# 輸出路徑與 Log 檔名皆加上時間戳
EXP_GROUP_DIR = root_path / "results" / f"group2_botsort_bytetrack_{BATCH_TIMESTAMP}"
LOG_FILE_PATH = EXP_GROUP_DIR / f"batch_experiments_log_{BATCH_TIMESTAMP}.csv"

# ============================================
# ⚙️ 輔助函式
# ============================================
def log_experiment_result(log_path, data_dict):
    df_new = pd.DataFrame([data_dict])
    log_path.parent.mkdir(parents=True, exist_ok=True)
    if not log_path.exists():
        df_new.to_csv(log_path, index=False)
    else:
        df_new.to_csv(log_path, mode='a', header=False, index=False)

def calc_fps(latency_ms):
    return 1000.0 / latency_ms if latency_ms > 0 else 0.0

# ============================================
# 🧪 核心實驗邏輯
# ============================================
def run_dataset_experiment(dataset_name, model):
    
    current_time = datetime.now().strftime("%H%M%S") # 用於子資料夾區分
    
    print(f"\n{'='*60}")
    print(f"📦 正在處理資料集: {dataset_name} (Time: {current_time})")
    print(f"{'='*60}")

    raw_path = root_path / "data" / dataset_name
    if not raw_path.exists():
        print(f"❌ 找不到資料夾: {raw_path}")
        return

    source_path = detect_source_type(raw_path)
    gt_path = raw_path / 'gt' / 'gt.txt'
    
    # 使用全域定義的輸出目錄
    TEST_ROOT_DIR = EXP_GROUP_DIR
    
    for conf in CONF_THRESHOLDS:
        for iou in IOU_THRESHOLDS:
            print(f"\n🔹 [Config] Dataset: {dataset_name} | Conf: {conf} | IoU: {iou}")
            
            # -------------------------------------------------
            # 1. Detection Only
            # -------------------------------------------------
            print(f"   👉 [Condition 1] Detection Only...")
            det_output_dir = TEST_ROOT_DIR / f"{dataset_name}_Det_c{conf}_iou{iou}_{current_time}"
            
            det_csv_path, lat_det = run_predict_on_validation_set(
                model, source_path, det_output_dir, imgsz=640, conf=conf, iou=iou, half=True
            )
            
            fps_det = calc_fps(lat_det)
            print(f"      ⏱️ Detection Latency: {lat_det:.2f} ms | FPS: {fps_det:.1f}")
            
            stab_det = compute_class_stability(det_csv_path)
            
            log_experiment_result(LOG_FILE_PATH, {
                "dataset": dataset_name, "conf": conf, "iou": iou,
                "tracker": "None", 
                "method": "detection", 
                "window": "None",
                "MOTA": np.nan, 
                "IDF1": np.nan, 
                "IDSW": np.nan,
                "instability": stab_det.get('class_instability_rate', np.nan),
                "latency_ms": lat_det, "FPS": fps_det,
                "timestamp": datetime.now().strftime("%Y-%m-%d %H:%M:%S")
            })
        
            # -------------------------------------------------
            # 2. Loop Trackers (BoTSORT, ByteTrack)
            # -------------------------------------------------
            for tracker_type in TRACKERS:
                print(f"\n   👉 [Condition 2] Running Tracker: {tracker_type} (Tracking Only)...")
                
                track_output_dir = TEST_ROOT_DIR / f"{dataset_name}_{tracker_type}_c{conf}_iou{iou}_{current_time}"
                track_output_dir.mkdir(parents=True, exist_ok=True)
                
                # run_tracker 回傳 avg_latency_ms (含 Det+Track)
                df_track, lat_track = run_tracker(
                    model, tracker_type, source_path, track_output_dir, imgsz=640, conf=conf, iou=iou, half=True, stream=True
                )
                
                if df_track.empty:
                    print(f"      ⚠️ {tracker_type} 結果為空，跳過。")
                    continue
                    
                fps_track = calc_fps(lat_track)
                print(f"      ⏱️ Tracking Latency: {lat_track:.2f} ms | FPS: {fps_track:.1f}")
        
                csv_name_raw = f"{tracker_type}_raw.csv"
                csv_path_raw = track_output_dir / csv_name_raw
                df_track.to_csv(csv_path_raw, index=False)
                
                stab_raw = compute_class_stability_with_id(csv_path_raw)
                mot_raw = compute_mot_metrics(csv_path_raw, gt_path) or {}
                
                log_experiment_result(LOG_FILE_PATH, {
                    "dataset": dataset_name, "conf": conf, "iou": iou,
                    "tracker": tracker_type, 
                    "method": "tracking", 
                    "window": "None",
                    "MOTA": mot_raw.get('MOTA', np.nan), 
                    "IDF1": mot_raw.get('IDF1', np.nan), 
                    "IDSW": mot_raw.get('IDSW', np.nan),
                    "instability": stab_raw.get('class_instability_rate_id', np.nan),
                    "latency_ms": lat_track, "FPS": fps_track,
                    "timestamp": datetime.now().strftime("%Y-%m-%d %H:%M:%S")
                })
                
                # 執行投票
                print(f"   👉 [Condition 3] Running Voting Analysis...")
                for vote_cfg in VOTING_SETTINGS:
                    method, window = vote_cfg['method'], vote_cfg['window']
                    
                    df_vote, lat_vote = run_class_voting(df_track, method, window, is_realtime=True)
                    
                    total_lat = lat_track + lat_vote
                    total_fps = calc_fps(total_lat)
        
                    csv_name_vote = f"{tracker_type}_{method}_w{window}.csv"
                    csv_path_vote = track_output_dir / csv_name_vote
                    df_vote.to_csv(csv_path_vote, index=False)
        
                    stab_vote = compute_class_stability_with_id(csv_path_vote)
                    mot_vote = compute_mot_metrics(csv_path_vote, gt_path) or {}
                    
                    log_experiment_result(LOG_FILE_PATH, {
                        "dataset": dataset_name, "conf": conf, "iou": iou,
                        "tracker": tracker_type, 
                        "method": method, 
                        "window": window,
                        "MOTA": mot_vote.get('MOTA', np.nan), 
                        "IDF1": mot_vote.get('IDF1', np.nan), 
                        "IDSW": mot_vote.get('IDSW', np.nan),
                        "instability": stab_vote.get('class_instability_rate_id', np.nan),
                        "latency_ms": total_lat, "FPS": total_fps,
                        "timestamp": datetime.now().strftime("%Y-%m-%d %H:%M:%S")
                    })

# ============================================
# 🚀 主程式入口
# ============================================
if __name__ == "__main__":
    print(f"📦 開始執行 Group 2 實驗 (BoTSORT, ByteTrack)")
    print(f"📂 輸出目錄: {EXP_GROUP_DIR}")
    print(f"📝 Log 檔案: {LOG_FILE_PATH}")
    
    model = load_model(root_path / DETECTOR_WEIGHT)
    
    print("🔥 正在進行 GPU 暖身 (Warm-up)...")
    try:
        dummy_input = torch.zeros(1, 3, 640, 640).to(model.device)
        for _ in range(3):
            model(dummy_input, verbose=False)
        print("✅ 暖身完成！GPU 已準備就緒。")
    except Exception as e:
        print(f"⚠️ 暖身失敗 (可能是 CPU 模式): {e}")

    for dataset in TARGET_DATASETS:
        try:
            run_dataset_experiment(dataset, model)
        except Exception as e:
            print(f"❌ 資料集 {dataset} 發生錯誤: {e}")
            traceback.print_exc()
    print(f"\n🎉 Group 2 實驗完成！結果已存至: {LOG_FILE_PATH}")
# Out:
# WARNING  Ultralytics settings reset to default values. This may be due to a possible problem with your settings or a recent ultralytics package update.
# View Ultralytics Settings with 'yolo settings' or at 'C:\Users\USER\AppData\Roaming\Ultralytics\settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# 📦 開始執行 Group 2 實驗 (BoTSORT, ByteTrack)
# 📂 輸出目錄: D:\experiment\YOLO11_Experiment\results\group2_botsort_bytetrack_20260102-195606
# 📝 Log 檔案: D:\experiment\YOLO11_Experiment\results\group2_botsort_bytetrack_20260102-195606\batch_experiments_log_20260102-195606.csv
# 🔥 正在進行 GPU 暖身 (Warm-up)...
# ✅ 暖身完成！GPU 已準備就緒。
#
# ============================================================
# 📦 正在處理資料集: 20230417_06_00230 (Time: 195608)
# ============================================================
#
# 🔹 [Config] Dataset: 20230417_06_00230 | Conf: 0.3 | IoU: 0.3
#    👉 [Condition 1] Detection Only...
#
# ✅ 儲存驗證集結果: D:\experiment\YOLO11_Experiment\results\group2_botsort_bytetrack_20260102-195606\20230417_06_00230_Det_c0.3_iou0.3_195608\20230417_06_00230_predictions.csv
#    ⏱️ 偵測耗時: 4008.69 ms
#       ⏱️ Detection Latency: 20.04 ms | FPS: 49.9
#
#    👉 [Condition 2] Running Tracker: botsort (Tracking Only)...
#
# ✅ 正在執行 botsort 追蹤，來源: D:\experiment\YOLO11_Experiment\data\20230417_06_00230\images...
#
# 🔄 正在執行追蹤迴圈 (Detect + Track)...
#    Processing frame 190...
#    ⏱️ 追蹤總運算耗時: 5075.48 ms
#       ⏱️ Tracking Latency: 27.29 ms | FPS: 36.6
#    👉 [Condition 3] Running Voting Analysis...
#    ... 對 1 個目標進行 [majority] 投票 (Win: 3, Mode: Real-time)
#    ⏱️ 投票運算耗時: 16.74 ms (平均 0.0900 ms/frame)
#    ... 對 1 個目標進行 [majority] 投票 (Win: 5, Mode: Real-time)
#    ⏱️ 投票運算耗時: 22.41 ms (平均 0.1205 ms/frame)
#    ... 對 1 個目標進行 [majority] 投票 (Win: 10, Mode: Real-time)
#    ⏱️ 投票運算耗時: 23.32 ms (平均 0.1254 ms/frame)
#    ... 對 1 個目標進行 [majority] 投票 (Win: all, Mode: Real-time)
#    ⏱️ 投票運算耗時: 18.28 ms (平均 0.0983 ms/frame)
#    ... 對 1 個目標進行 [weighted] 投票 (Win: 3, Mode: Real-time)
#    ⏱️ 投票運算耗時: 67.19 ms (平均 0.3612 ms/frame)
#    ... 對 1 個目標進行 [weighted] 投票 (Win: 5, Mode: Real-time)
#    ⏱️ 投票運算耗時: 81.07 ms (平均 0.4359 ms/frame)
#    ... 對 1 個目標進行 [weighted] 投票 (Win: 10, Mode: Real-time)
#    ⏱️ 投票運算耗時: 79.11 ms (平均 0.4253 ms/frame)
#    ... 對 1 個目標進行 [weighted] 投票 (Win: all, Mode: Real-time)
#    ⏱️ 投票運算耗時: 80.64 ms (平均 0.4336 ms/frame)
#
#    👉 [Condition 2] Running Tracker: bytetrack (Tracking Only)...
#
# ✅ 正在執行 bytetrack 追蹤，來源: D:\experiment\YOLO11_Experiment\data\20230417_06_00230\images...
#
# 🔄 正在執行追蹤迴圈 (Detect + Track)...
#    Processing frame 190...
#    ⏱️ 追蹤總運算耗時: 4638.92 ms
#       ⏱️ Tracking Latency: 24.94 ms | FPS: 40.1
#    👉 [Condition 3] Running Voting Analysis...
#    ... 對 1 個目標進行 [majority] 投票 (Win: 3, Mode: Real-time)
#    ⏱️ 投票運算耗時: 18.15 ms (平均 0.0976 ms/frame)
#    ... 對 1 個目標進行 [majority] 投票 (Win: 5, Mode: Real-time)
#    ⏱️ 投票運算耗時: 18.48 ms (平均 0.0993 ms/frame)
#    ... 對 1 個目標進行 [majority] 投票 (Win: 10, Mode: Real-time)
#    ⏱️ 投票運算耗時: 18.41 ms (平均 0.0990 ms/frame)
#    ... 對 1 個目標進行 [majority] 投票 (Win: all, Mode: Real-time)
#    ⏱️ 投票運算耗時: 18.14 ms (平均 0.0975 ms/frame)
#    ... 對 1 個目標進行 [weighted] 投票 (Win: 3, Mode: Real-time)
#    ⏱️ 投票運算耗時: 79.94 ms (平均 0.4298 ms/frame)
#    ... 對 1 個目標進行 [weighted] 投票 (Win: 5, Mode: Real-time)
#    ⏱️ 投票運算耗時: 76.43 ms (平均 0.4109 ms/frame)
#    ... 對 1 個目標進行 [weighted] 投票 (Win: 10, Mode: Real-time)
#    ⏱️ 投票運算耗時: 76.16 ms (平均 0.4095 ms/frame)
#    ... 對 1 個目標進行 [weighted] 投票 (Win: all, Mode: Real-time)
#    ⏱️ 投票運算耗時: 76.27 ms (平均 0.4101 ms/frame)
#
#    👉 [Condition 2] Running Tracker: botsort_reid (Tracking Only)...
#
# ✅ 正在執行 botsort_reid 追蹤，來源: D:\experiment\YOLO11_Experiment\data\20230417_06_00230\images...
#
# 🔄 正在執行追蹤迴圈 (Detect + Track)...
#    Processing frame 190...
#    ⏱️ 追蹤總運算耗時: 5159.45 ms
#       ⏱️ Tracking Latency: 27.74 ms | FPS: 36.1
#    👉 [Condition 3] Running Voting Analysis...
#    ... 對 1 個目標進行 [majority] 投票 (Win: 3, Mode: Real-time)
#    ⏱️ 投票運算耗時: 17.75 ms (平均 0.0954 ms/frame)
#    ... 對 1 個目標進行 [majority] 投票 (Win: 5, Mode: Real-time)
#    ⏱️ 投票運算耗時: 18.28 ms (平均 0.0983 ms/frame)
#    ... 對 1 個目標進行 [majority] 投票 (Win: 10, Mode: Real-time)
#    ⏱️ 投票運算耗時: 27.40 ms (平均 0.1473 ms/frame)
#    ... 對 1 個目標進行 [majority] 投票 (Win: all, Mode: Real-time)
#    ⏱️ 投票運算耗時: 18.06 ms (平均 0.0971 ms/frame)
#    ... 對 1 個目標進行 [weighted] 投票 (Win: 3, Mode: Real-time)
#    ⏱️ 投票運算耗時: 78.01 ms (平均 0.4194 ms/frame)
#    ... 對 1 個目標進行 [weighted] 投票 (Win: 5, Mode: Real-time)
#    ⏱️ 投票運算耗時: 90.12 ms (平均 0.4845 ms/frame)
#    ... 對 1 個目標進行 [weighted] 投票 (Win: 10, Mode: Real-time)
#    ⏱️ 投票運算耗時: 76.45 ms (平均 0.4110 ms/frame)
#    ... 對 1 個目標進行 [weighted] 投票 (Win: all, Mode: Real-time)
#    ⏱️ 投票運算耗時: 82.23 ms (平均 0.4421 ms/frame)
#
# 🔹 [Config] Dataset: 20230417_06_00230 | Conf: 0.3 | IoU: 0.7
#    👉 [Condition 1] Detection Only...
#
# ✅ 儲存驗證集結果: D:\experiment\YOLO11_Experiment\results\group2_botsort_bytetrack_20260102-195606
ms/frame)
#    ... 對 1 個目標進行 [weighted] 投票 (Win: 10, Mode: Real-time)
#    ⏱️ 投票運算耗時: 11.03 ms (平均 0.4797 ms/frame)
#    ... 對 1 個目標進行 [weighted] 投票 (Win: all, Mode: Real-time)
#    ⏱️ 投票運算耗時: 10.64 ms (平均 0.4626 ms/frame)
#
#    👉 [Condition 2] Running Tracker: bytetrack (Tracking Only)...
#
# ✅ 正在執行 bytetrack 追蹤，來源: D:\experiment\YOLO11_Experiment\data\IMG_0057\images...
#
# 🔄 正在執行追蹤迴圈 (Detect + Track)...
#    Processing frame 590...
#    ⏱️ 追蹤總運算耗時: 16697.30 ms
#       ⏱️ Tracking Latency: 725.97 ms | FPS: 1.4
#    👉 [Condition 3] Running Voting Analysis...
#    ... 對 1 個目標進行 [majority] 投票 (Win: 3, Mode: Real-time)
#    ⏱️ 投票運算耗時: 3.47 ms (平均 0.1510 ms/frame)
#    ... 對 1 個目標進行 [majority] 投票 (Win: 5, Mode: Real-time)
#    ⏱️ 投票運算耗時: 3.24 ms (平均 0.1410 ms/frame)
#    ... 對 1 個目標進行 [majority] 投票 (Win: 10, Mode: Real-time)
#    ⏱️ 投票運算耗時: 7.29 ms (平均 0.3168 ms/frame)
#    ... 對 1 個目標進行 [majority] 投票 (Win: all, Mode: Real-time)
#    ⏱️ 投票運算耗時: 3.74 ms (平均 0.1626 ms/frame)
#    ... 對 1 個目標進行 [weighted] 投票 (Win: 3, Mode: Real-time)
#    ⏱️ 投票運算耗時: 10.57 ms (平均 0.4595 ms/frame)
#    ... 對 1 個目標進行 [weighted] 投票 (Win: 5, Mode: Real-time)
#    ⏱️ 投票運算耗時: 10.78 ms (平均 0.4687 ms/frame)
#    ... 對 1 個目標進行 [weighted] 投票 (Win: 10, Mode: Real-time)
#    ⏱️ 投票運算耗時: 10.54 ms (平均 0.4584 ms/frame)
#    ... 對 1 個目標進行 [weighted] 投票 (Win: all, Mode: Real-time)
#    ⏱️ 投票運算耗時: 12.23 ms (平均 0.5317 ms/frame)
#
#    👉 [Condition 2] Running Tracker: botsort_reid (Tracking Only)...
#
# ✅ 正在執行 botsort_reid 追蹤，來源: D:\experiment\YOLO11_Experiment\data\IMG_0057\images...
#
# 🔄 正在執行追蹤迴圈 (Detect + Track)...
#    Processing frame 590...
#    ⏱️ 追蹤總運算耗時: 16959.03 ms
#       ⏱️ Tracking Latency: 737.35 ms | FPS: 1.4
#    👉 [Condition 3] Running Voting Analysis...
#    ... 對 1 個目標進行 [majority] 投票 (Win: 3, Mode: Real-time)
#    ⏱️ 投票運算耗時: 3.06 ms (平均 0.1331 ms/frame)
#    ... 對 1 個目標進行 [majority] 投票 (Win: 5, Mode: Real-time)
#    ⏱️ 投票運算耗時: 3.61 ms (平均 0.1571 ms/frame)
#    ... 對 1 個目標進行 [majority] 投票 (Win: 10, Mode: Real-time)
#    ⏱️ 投票運算耗時: 3.40 ms (平均 0.1480 ms/frame)
#    ... 對 1 個目標進行 [majority] 投票 (Win: all, Mode: Real-time)
#    ⏱️ 投票運算耗時: 4.13 ms (平均 0.1794 ms/frame)
#    ... 對 1 個目標進行 [weighted] 投票 (Win: 3, Mode: Real-time)
#    ⏱️ 投票運算耗時: 11.24 ms (平均 0.4885 ms/frame)
#    ... 對 1 個目標進行 [weighted] 投票 (Win: 5, Mode: Real-time)
#    ⏱️ 投票運算耗時: 11.20 ms (平均 0.4869 ms/frame)
#    ... 對 1 個目標進行 [weighted] 投票 (Win: 10, Mode: Real-time)
#    ⏱️ 投票運算耗時: 11.28 ms (平均 0.4903 ms/frame)
#    ... 對 1 個目標進行 [weighted] 投票 (Win: all, Mode: Real-time)
#    ⏱️ 投票運算耗時: 10.93 ms (平均 0.4750 ms/frame)
#
# 🔹 [Config] Dataset: IMG_0057 | Conf: 0.5 | IoU: 0.7
#    👉 [Condition 1] Detection Only...
#
# ✅ 儲存驗證集結果: D:\experiment\YOLO11_Experiment\results\group2_botsort_bytetrack_20260102-195606\IMG_0057_Det_c0.5_iou0.7_204841\IMG_0057_predictions.csv
#    ⏱️ 偵測耗時: 16694.33 ms
#       ⏱️ Detection Latency: 27.82 ms | FPS: 35.9
#
#    👉 [Condition 2] Running Tracker: botsort (Tracking Only)...
#
# ✅ 正在執行 botsort 追蹤，來源: D:\experiment\YOLO11_Experiment\data\IMG_0057\images...
#
# 🔄 正在執行追蹤迴圈 (Detect + Track)...
#    Processing frame 590...
#    ⏱️ 追蹤總運算耗時: 16902.66 ms
#       ⏱️ Tracking Latency: 734.90 ms | FPS: 1.4
#    👉 [Condition 3] Running Voting Analysis...
#    ... 對 1 個目標進行 [majority] 投票 (Win: 3, Mode: Real-time)
#    ⏱️ 投票運算耗時: 3.14 ms (平均 0.1364 ms/frame)
#    ... 對 1 個目標進行 [majority] 投票 (Win: 5, Mode: Real-time)
#    ⏱️ 投票運算耗時: 4.43 ms (平均 0.1925 ms/frame)
#    ... 對 1 個目標進行 [majority] 投票 (Win: 10, Mode: Real-time)
#    ⏱️ 投票運算耗時: 3.53 ms (平均 0.1533 ms/frame)
#    ... 對 1 個目標進行 [majority] 投票 (Win: all, Mode: Real-time)
#    ⏱️ 投票運算耗時: 3.30 ms (平均 0.1433 ms/frame)
#    ... 對 1 個目標進行 [weighted] 投票 (Win: 3, Mode: Real-time)
#    ⏱️ 投票運算耗時: 10.95 ms (平均 0.4761 ms/frame)
#    ... 對 1 個目標進行 [weighted] 投票 (Win: 5, Mode: Real-time)
#    ⏱️ 投票運算耗時: 10.78 ms (平均 0.4689 ms/frame)
#    ... 對 1 個目標進行 [weighted] 投票 (Win: 10, Mode: Real-time)
#    ⏱️ 投票運算耗時: 10.99 ms (平均 0.4776 ms/frame)
#    ... 對 1 個目標進行 [weighted] 投票 (Win: all, Mode: Real-time)
#    ⏱️ 投票運算耗時: 11.28 ms (平均 0.4904 ms/frame)
#
#    👉 [Condition 2] Running Tracker: bytetrack (Tracking Only)...
#
# ✅ 正在執行 bytetrack 追蹤，來源: D:\experiment\YOLO11_Experiment\data\IMG_0057\images...
#
# 🔄 正在執行追蹤迴圈 (Detect + Track)...
#    Processing frame 590...
#    ⏱️ 追蹤總運算耗時: 16679.60 ms
#       ⏱️ Tracking Latency: 725.20 ms | FPS: 1.4
#    👉 [Condition 3] Running Voting Analysis...
#    ... 對 1 個目標進行 [majority] 投票 (Win: 3, Mode: Real-time)
#    ⏱️ 投票運算耗時: 5.46 ms (平均 0.2375 ms/frame)
#    ... 對 1 個目標進行 [majority] 投票 (Win: 5, Mode: Real-time)
#    ⏱️ 投票運算耗時: 3.47 ms (平均 0.1509 ms/frame)
#    ... 對 1 個目標進行 [majority] 投票 (Win: 10, Mode: Real-time)
#    ⏱️ 投票運算耗時: 3.44 ms (平均 0.1496 ms/frame)
#    ... 對 1 個目標進行 [majority] 投票 (Win: all, Mode: Real-time)
#    ⏱️ 投票運算耗時: 3.45 ms (平均 0.1498 ms/frame)
#    ... 對 1 個目標進行 [weighted] 投票 (Win: 3, Mode: Real-time)
#    ⏱️ 投票運算耗時: 11.37 ms (平均 0.4945 ms/frame)
#    ... 對 1 個目標進行 [weighted] 投票 (Win: 5, Mode: Real-time)
#    ⏱️ 投票運算耗時: 11.88 ms (平均 0.5167 ms/frame)
#    ... 對 1 個目標進行 [weighted] 投票 (Win: 10, Mode: Real-time)
#    ⏱️ 投票運算耗時: 10.73 ms (平均 0.4666 ms/frame)
#    ... 對 1 個目標進行 [weighted] 投票 (Win: all, Mode: Real-time)
#    ⏱️ 投票運算耗時: 10.76 ms (平均 0.4677 ms/frame)
#
#    👉 [Condition 2] Running Tracker: botsort_reid (Tracking Only)...
#
# ✅ 正在執行 botsort_reid 追蹤，來源: D:\experiment\YOLO11_Experiment\data\IMG_0057\images...
#
# 🔄 正在執行追蹤迴圈 (Detect + Track)...
#    Processing frame 590...
#    ⏱️ 追蹤總運算耗時: 16917.38 ms
#       ⏱️ Tracking Latency: 735.54 ms | FPS: 1.4
#    👉 [Condition 3] Running Voting Analysis...
#    ... 對 1 個目標進行 [majority] 投票 (Win: 3, Mode: Real-time)
#    ⏱️ 投票運算耗時: 3.32 ms (平均 0.1445 ms/frame)
#    ... 對 1 個目標進行 [majority] 投票 (Win: 5, Mode: Real-time)
#    ⏱️ 投票運算耗時: 3.70 ms (平均 0.1610 ms/frame)
#    ... 對 1 個目標進行 [majority] 投票 (Win: 10, Mode: Real-time)
#    ⏱️ 投票運算耗時: 3.35 ms (平均 0.1455 ms/frame)
#    ... 對 1 個目標進行 [majority] 投票 (Win: all, Mode: Real-time)
#    ⏱️ 投票運算耗時: 3.46 ms (平均 0.1506 ms/frame)
#    ... 對 1 個目標進行 [weighted] 投票 (Win: 3, Mode: Real-time)
#    ⏱️ 投票運算耗時: 11.13 ms (平均 0.4840 ms/frame)
#    ... 對 1 個目標進行 [weighted] 投票 (Win: 5, Mode: Real-time)
#    ⏱️ 投票運算耗時: 10.93 ms (平均 0.4750 ms/frame)
#    ... 對 1 個目標進行 [weighted] 投票 (Win: 10, Mode: Real-time)
#    ⏱️ 投票運算耗時: 16.74 ms (平均 0.7278 ms/frame)
#    ... 對 1 個目標進行 [weighted] 投票 (Win: all, Mode: Real-time)
#    ⏱️ 投票運算耗時: 11.34 ms (平均 0.4929 ms/frame)
#
# 🎉 Group 2 實驗完成！結果已存至: D:\experiment\YOLO11_Experiment\results\group2_botsort_bytetrack_20260102-195606\batch_experiments_log_20260102-195606.csv
